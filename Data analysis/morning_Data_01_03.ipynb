# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd

import FiltradoMedia as fm #library for data processing

# %% [markdown]
# # Data display and adjustment

# %%
a_1_03_82_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_8_20-8_34_b_01_03.TXT')
R_a_1_03_82_halley = fm.ajuste_int(a_1_03_82_halley)


fig = plt.figure(figsize=(18, 11))
plt.title('8:20-8:34', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 

plt.errorbar(a_1_03_82_halley[3],a_1_03_82_halley[1], yerr = a_1_03_82_halley[2],
             xerr = a_1_03_82_halley[4], linestyle=None, color='m', ms=5,fmt="s",capsize=5,
             capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_82_halley[0], R_a_1_03_82_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
#norte-sur, calculation of the inclination of the polarization vector
pos_min = np.where(R_a_1_03_82_halley[1]==min(R_a_1_03_82_halley[1]))
R_a_1_03_82_halley[0][pos_min]
# Out:
# array([165., 345.])

# %%
error = (194-(360-165))/194 * 100
error
# Out:
# -0.5154639175257731

# %%
a_1_03_8_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_8_40-8_50.TXT')
R_a_1_03_8_halley = fm.ajuste_int(a_1_03_8_halley)


fig = plt.figure(figsize=(18, 11))
plt.title('8:40-8:50', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 


plt.errorbar(a_1_03_8_halley[3],a_1_03_8_halley[1], yerr = a_1_03_8_halley[2], xerr = a_1_03_8_halley[4], 
             linestyle=None, color='m', ms=5,fmt="s",capsize=5, capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_8_halley[0], R_a_1_03_8_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.ylim((400,520))
plt.show()

# %%
#norte-sur, calculation of the inclination of the polarization vector
pos_min = np.where(R_a_1_03_8_halley[1]==min(R_a_1_03_8_halley[1]))
R_a_1_03_8_halley[0][pos_min]
# Out:
# array([155., 335.])

# %%
error = (195-(360-155))/195 * 100
error
# Out:
# -5.128205128205128

# %%
a_1_03_9_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_9_00-9_08.TXT')
R_a_1_03_9_halley = fm.ajuste_int(a_1_03_9_halley)
a_1_03_9_halley[2][3]=1

fig = plt.figure(figsize=(18, 11))
plt.title('9:00-9:08', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 

plt.errorbar(a_1_03_9_halley[3], a_1_03_9_halley[1], yerr = a_1_03_9_halley[2], xerr = a_1_03_9_halley[4], 
             linestyle= None, color='m', ms=5,fmt="s",capsize=5, capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_9_halley[0], R_a_1_03_9_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.ylim((450,550))
plt.show()

# %%
#norte-sur, calculation of the inclination of the polarization vector
pos_min = np.where(R_a_1_03_9_halley[1]==min(R_a_1_03_9_halley[1]))
R_a_1_03_9_halley[0][pos_min]
# Out:
# array([150., 330.])

# %%
error = (197-(360-150))/197 * 100
error
# Out:
# -6.598984771573605

# %%
a_1_03_92_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_9_20.TXT')
R_a_1_03_92_halley = fm.ajuste_int(a_1_03_92_halley)
a_1_03_92_halley[2][4] = 1
a_1_03_92_halley[2][39] = 1

fig = plt.figure(figsize=(18, 11))
plt.title('9:20', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 
plt.errorbar(a_1_03_92_halley[3],a_1_03_92_halley[1], yerr = a_1_03_92_halley[2], 
             xerr = a_1_03_92_halley[4], linestyle=None, color='m', ms=5,fmt="s",capsize=5, 
             capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_92_halley[0], R_a_1_03_92_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.ylim((510,580))
# Out:
# (510.0, 580.0)

# %%
#norte-sur, calculation of the inclination of the polarization vector
pos_min = np.where(R_a_1_03_92_halley[1]==min(R_a_1_03_92_halley[1]))
R_a_1_03_92_halley[0][pos_min]
# Out:
# array([130., 310.])

# %%
error = (199-(360-130))/199 * 100
error
# Out:
# -15.577889447236181

# %%
a_1_03_10_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_10_00.TXT')
R_a_1_03_10_halley = fm.ajuste_int(a_1_03_10_halley)


fig = plt.figure(figsize=(18, 11))
plt.title('10:00', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 


plt.errorbar(a_1_03_10_halley[3],a_1_03_10_halley[1], yerr = a_1_03_10_halley[2], 
             xerr = a_1_03_10_halley[4], linestyle=None, color='m', ms=5,fmt="s",capsize=5,
             capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_10_halley[0], R_a_1_03_10_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
#norte-sur, calculation of the inclination of the polarization vector
pos_min = np.where(R_a_1_03_10_halley[1]==min(R_a_1_03_10_halley[1]))
R_a_1_03_10_halley[0][pos_min]
# Out:
# array([150., 330.])

# %%
error = (205-(360-150))/200 * 100
error
# Out:
# -2.5

# %%
a_1_03_10_30_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_10_30.TXT')
R_a_1_03_10_30_halley = fm.ajuste_int(a_1_03_10_30_halley)


fig = plt.figure(figsize=(18, 11))
plt.title('10:30', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 

plt.errorbar(a_1_03_10_30_halley[3], a_1_03_10_30_halley[1], yerr = a_1_03_10_30_halley[2],
             xerr = a_1_03_10_30_halley[4], linestyle=None, color='m', ms=5,fmt="s",capsize=5, 
             capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_10_30_halley[0], R_a_1_03_10_30_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
#norte-sur, calculation of the inclination of the polarization vector
pos_min = np.where(R_a_1_03_10_30_halley[1]==min(R_a_1_03_10_30_halley[1]))
R_a_1_03_10_30_halley[0][pos_min]
# Out:
# array([150., 330.])

# %%
error = (211-(360-150))/211 * 100
error
# Out:
# 0.47393364928909953

# %%
a_1_03_11_00_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_11_00.TXT')
R_a_1_03_11_00_halley = fm.ajuste_int(a_1_03_11_00_halley)


fig = plt.figure(figsize=(18, 11))
plt.title('11:00', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 

plt.errorbar(a_1_03_11_00_halley[3], a_1_03_11_00_halley[1], yerr = a_1_03_11_00_halley[2],
             xerr = a_1_03_11_00_halley[4], linestyle=None, color='m', ms=5,fmt="s",capsize=5,
             capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_11_00_halley[0], R_a_1_03_11_00_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
#norte-sur, calculation of the inclination of the polarization vector
pos_min = np.where(R_a_1_03_11_00_halley[1]==min(R_a_1_03_11_00_halley[1]))
R_a_1_03_11_00_halley[0][pos_min]
# Out:
# array([155., 335.])

# %%
error = (222-(360-155))/222 * 100
error
# Out:
# 7.657657657657657

# %%
a_1_03_11_30_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_11_30.TXT')
R_a_1_03_11_30_halley = fm.ajuste_int(a_1_03_11_30_halley)


fig = plt.figure(figsize=(18, 11))
plt.title('11:30', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 

plt.errorbar(a_1_03_11_30_halley[3], a_1_03_11_30_halley[1], yerr = a_1_03_11_30_halley[2], 
             xerr = a_1_03_11_30_halley[4], linestyle=None, color='m', ms=5,fmt="s",capsize=5, 
             capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_11_30_halley[0], R_a_1_03_11_30_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
a_1_03_12_00_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_12_00.TXT')
R_a_1_03_12_00_halley = fm.ajuste_int(a_1_03_12_00_halley)


fig = plt.figure(figsize=(18, 11))
plt.title('12:00', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 

plt.errorbar(a_1_03_12_00_halley[3], a_1_03_12_00_halley[1], yerr = a_1_03_12_00_halley[2], 
             xerr = a_1_03_12_00_halley[4], linestyle=None, color='m', ms=5,fmt="s",capsize=5, 
             capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_12_00_halley[0], R_a_1_03_12_00_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
a_1_03_12_10_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_12_10.TXT')
R_a_1_03_12_10_halley = fm.ajuste_int(a_1_03_12_10_halley)


fig = plt.figure(figsize=(18, 11))
plt.title('12:10', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 

plt.errorbar(a_1_03_12_10_halley[3], a_1_03_12_10_halley[1], yerr = a_1_03_12_10_halley[2], 
             xerr = a_1_03_12_10_halley[4], linestyle=None, color='m', ms=5,fmt="s",
             capsize=5, capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_12_10_halley[0], R_a_1_03_12_10_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
#norte-sur, calculation of the inclination of the polarization vector
pos_min = np.where(R_a_1_03_12_10_halley[1]==min(R_a_1_03_12_10_halley[1]))
R_a_1_03_12_10_halley[0][pos_min]
# Out:
# array([ 60., 240.])

# %%
error = (274-(360-60))/274 * 100
error
# Out:
# -9.48905109489051

# %%
a_1_03_12_42_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_12_36_-12_42n.TXT')
R_a_1_03_12_42_halley = fm.ajuste_int(a_1_03_12_42_halley)
a_1_03_12_42_halley[2][10] = 1

fig = plt.figure(figsize=(18, 11))
plt.title('12:42', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 

plt.errorbar(a_1_03_12_42_halley[3], a_1_03_12_42_halley[1], yerr = a_1_03_12_42_halley[2], 
             xerr = a_1_03_12_42_halley[4], linestyle=None, color='m', ms=5,fmt="s", 
             capsize=5, capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_12_42_halley[0], R_a_1_03_12_42_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.ylim((650,800))
plt.show()

# %%
a_1_03_12_50_halley = fm.datos_int(dir_data = '01_03_2020/morning/DATALOG_12_50-12_58_n.TXT')
R_a_1_03_12_50_halley = fm.ajuste_int(a_1_03_12_50_halley)


fig = plt.figure(figsize=(18, 11))
plt.title('12:50', size = 20)
plt.xlabel('degrees [°]', fontsize = 20)                 
plt.ylabel('voltage [a.u]', fontsize = 20) 

plt.errorbar(a_1_03_12_50_halley[3], a_1_03_12_50_halley[1], yerr = a_1_03_12_50_halley[2],
             xerr = a_1_03_12_50_halley[4], linestyle=None, color='m', ms=5,fmt="s",capsize=5, 
             capthick=1, label = r'$V^*$')
plt.plot(R_a_1_03_12_50_halley[0], R_a_1_03_12_50_halley[1], 'b-')
plt.grid()
plt.legend(fontsize = 18, loc=0)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
#norte-sur, calculation of the inclination of the polarization vector
pos_min = np.where(R_a_1_03_12_50_halley[1]==min(R_a_1_03_12_50_halley[1]))
R_a_1_03_12_50_halley[0][pos_min]
# Out:
# array([105., 285.])

# %%
error = (307-(360-105))/285 * 100
error
# Out:
# 18.24561403508772
